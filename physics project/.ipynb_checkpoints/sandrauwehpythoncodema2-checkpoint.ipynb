# %%
import math
import tkinter as tk
from PIL import Image, ImageTk

#Actual Calculation Function
def calc ():
 #Parameters
 global v, b, a, q, m, F, m, A
 v= float(vel.get())
 b = float(mag.get())
 a = float(ang.get())
 q= 1.6*10**(-19)
 m = 9.1*10**(-31)
 F = q*v*b*math.sin(math.radians(a))
 A = F/m

 #Answer window
 global window1
 window.destroy()
 window1 = tk.Tk()
 window1.title('Answer')
 window1.geometry('500x300')
 window1.config( bg="#e5d3f4")


 label1 = tk.Label(window1, text= f"The Magnetic Force = {F} N\n\n The Acceleration = {A} m/s^2",font='10', bg="#e5d3f4")
 label1.place(relx=0.5, rely=0.3, anchor = 'center')

 labe = tk.Label(window1, text = 'Would you like the step by step process on how to calculate it?', font='10', bg="#e5d3f4")
 labe.place(relx=0.5, rely= 0.5, anchor='center')
 button = tk.Button(window1, text= '   Yes   ', command= process)
 button.place(relx=0.4, rely= 0.6, anchor='center')
 button1 = tk.Button(window1, text= '   No   ',command= window1.destroy)
 button1.place(relx=0.6, rely=0.6, anchor='center')

#process
def process ():
 window1.destroy()
 window = tk.Tk()
 window.title('process')
 window.geometry('500x300')
 window.config( bg="#e5d3f4")

 la= tk.Label(window, text='PROCESS', font='10',  bg="#e5d3f4")
 la.place(relx=0.5, rely=0.1, anchor='center')
 label= tk.Label(window, text='Let:\n v= velocity of electron,   b= magnetic field\n  a= angle between mag. field and electron,   q= 1.6x10^-19C\n  F= mag. force  m= 9.1x10^-31kg,  A= acceleration',  bg="#e5d3f4")
 label.place(relx=0.5, rely=0.3, anchor='center')
 la1= tk.Label(window, text=f'\nF= q x v x b x sin(a)\n A= F/m\n\n F={q} x {v} x {b} x sin({a})\n F={F}N\n\n A= ({F})/({m})\n A={A}m/s^2',  bg="#e5d3f4")
 la1.place(relx=0.5, rely=0.65, anchor='center')

#Hide Question Function
def hide ():
 labelq.destroy()
 button1.destroy()

#Show Question Function
def question ():
 global labelq
 labelq= tk.Label(window, text = "An eletron (mass,m=9.1 x 10^-31 kg, charge,q=1.6 x 10^-19 C) travels with\n a speed of 2.0 x 10^6m/s at an angle of 30 degrees\n with the direction of a magnetic field of 0.5T in the +y direction.What are\n (a) the magnitude of the magnetic force on the electron and \n(b) its acceleration?", bg="#f4d3f1")
 labelq.place(relx=0.5,rely= 0.4, anchor='center')
 global button1
 button1 = tk.Button(window, text='Hide Question', command= hide, relief= tk.FLAT)
 button1.place(relx=0.5,rely= 0.52, anchor='center')


#input/welcome window
window = tk.Tk()
window.geometry('500x500')
window.title('Input')
window.config(bg ='light blue')

bg = Image.open('background.png')
bg1 = ImageTk.PhotoImage(bg)
label0= tk.Label(window, image=bg1)
label0.pack()

label = tk.Label(window, text="Welcome to Sandra Uweh's Magnetic Calculator",font='10', bg="#e5d3f4")
label.place(relx=0.5,rely=0.12, anchor= 'center')

label1= tk.Label(window, text="This calculator answers question 14.7 in section 4 of the SAQ questions",bg='#e5d3f4')
label1.place(relx=0.5,rely=0.2, anchor= 'center')

label2= tk.Label(window, text="However it can be used to solve questions with the exact same format but with different\n values for the parameters",bg='#e5d3f4')
label2.place(relx=0.5,rely=0.28, anchor= 'center')

#magnetic field entry
label3= tk.Label(window, text="Please input your value for magnetic field strength (B):",bg='#e5d3f4')
label3.place(relx=0.5,rely=0.58, anchor= 'center')
mag = tk.Entry(window )
mag.place(relx=0.5,rely=0.62, anchor= 'center')

#velocity field entry
label4= tk.Label(window, text="Please input your value for velocity of the electron (v):",bg='#e5d3f4')
label4.place(relx=0.5,rely=0.66, anchor= 'center')
vel = tk.Entry(window)
vel.place(relx=0.5,rely=0.7, anchor= 'center')

#angle field entry
label5= tk.Label(window, text="Please input your value for angle between the electron and m-field(a):",bg='#e5d3f4')
label5.place(relx=0.5,rely=0.74, anchor= 'center')
ang = tk.Entry(window)
ang.place(relx=0.5,rely=0.78, anchor= 'center')

#Submit 
button2 = tk.Button(window, text= 'submit', command=calc, relief= tk.FLAT)
button2.place(relx= 0.5, rely= 0.85, anchor = 'center')

#Show Question button
button = tk.Button(window, text="Click me to see question", command= question,relief= tk.FLAT)
button.place(relx=0.5,rely=0.4, anchor='center')
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[56], line 74
#      72 bg = Image.open('background.png')
#      73 bg1 = ImageTk.PhotoImage(bg)
# ---> 74 label0= tk.Label(window, image=bg1)
#      75 label0.pack()
#      77 label = tk.Label(window, text="Welcome to Sandra Uweh's Magnetic Calculator",font='10', bg="#e5d3f4")
#
# File c:\Users\sandr\anaconda3\Lib\tkinter\__init__.py:3248, in Label.__init__(self, master, cnf, **kw)
#    3230 def __init__(self, master=None, cnf={}, **kw):
#    3231     """Construct a label widget with the parent MASTER.
#    3232
#    3233     STANDARD OPTIONS
#    (...)
#    3246
#    3247     """
# -> 3248     Widget.__init__(self, master, 'label', cnf, kw)
#
# File c:\Users\sandr\anaconda3\Lib\tkinter\__init__.py:2659, in BaseWidget.__init__(self, master, widgetName, cnf, kw, extra)
#    2657 for k, v in classes:
# ...

# %%
window = tk.Tk()
window.geometry('300x400')
def icons(a):
 icon = Image.open(a)
 icon1 = icon.resize((250,250))
 icon2 = ImageTk.PhotoImage(icon1)
 return icon2
 

create= icons('ICON.png')
background= icons('background.png')

button = tk.Button(window, image= create)
button.pack()
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[52], line 13
#      10 create= icons('ICON.png')
#      11 background= icons('background.png')
# ---> 13 button = tk.Button(window, image= create)
#      14 button.pack()
#      15 window.mainloop()
#
# File c:\Users\sandr\anaconda3\Lib\tkinter\__init__.py:2737, in Button.__init__(self, master, cnf, **kw)
#    2718 def __init__(self, master=None, cnf={}, **kw):
#    2719     """Construct a button widget with the parent MASTER.
#    2720
#    2721     STANDARD OPTIONS
#    (...)
#    2735         overrelief, state, width
#    2736     """
# -> 2737     Widget.__init__(self, master, 'button', cnf, kw)
#
# File c:\Users\sandr\anaconda3\Lib\tkinter\__init__.py:2659, in BaseWidget.__init__(self, master, widgetName, cnf, kw, extra)
#    2657 for k, v in classes:
#    2658     del cnf[k]
# -> 2659 self.tk.call(
# ...
